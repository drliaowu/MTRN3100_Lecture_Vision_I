# %% [markdown]
# # Pixels

# %% [markdown]
# # MTRN4110 20T2 Lecture Vision I OpenCV Examples

# %% [markdown]
# ## Import libraries

# %%
import cv2 # OpenCV library
import numpy as np # Numpy library for scientific computing
import matplotlib.pyplot as plt # Matplotlib library for plotting

# %% [markdown]
# ## Accessing pixel values

# %%
img = cv2.imread('opencv_logo.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # OpenCV reads an image in the BGR order by default, this function can change the order to RGB
plt.figure(figsize = (9, 5))
plt.imshow(img_rgb)
plt.show()

# %%
px_rgb = img_rgb[30, 100] # pixel value at row = 30, column = 100
print(px_rgb)
# Out:
# [255   0   0]

# %% [markdown]
# ## Grayscale image

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Change the color image to a grayscale image
plt.figure(figsize = (9, 5))
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
px_gray = img_gray[30, 100] # pixel value at row = 30, column = 100
print(px_gray)
# Out:
# 76

# %%
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img_rgb), ax1.set_title("RGB")
ax2.imshow(img_gray, cmap='gray'), ax2.set_title("Gray")
plt.show()

# %% [markdown]
# ## Image ROI

# %%
ROI = img_rgb[20:75, 65:135] # region of interest, rows: 20 - 75, columns: 65 - 135
plt.imshow(ROI)
plt.show()

# %%
img_rgb[80:135, 30:100] = ROI # replace the area of rows: 80 - 135, columns: 30 - 100 with the ROI
plt.figure(figsize = (9, 5))
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # reset img_rgb

# %% [markdown]
# # Perspective transformations

# %%
## Import libraries
import cv2 # OpenCV library
import numpy as np # Numpy library for scientific computing
import matplotlib.pyplot as plt # Matplotlib library for plotting

## Perspective tranformation
img = cv2.imread('sudoku.jpg') # read an image

pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]]) # four points on the first image
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]]) # four points on the second image

H = cv2.getPerspectiveTransform(pts1,pts2) # homography matrix

dst = cv2.warpPerspective(img, H, (300,300))

fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img), ax1.set_title("Original")
ax2.imshow(dst), ax2.set_title("Transformed")
plt.show()

# %% [markdown]
# # Colour spaces

# %%
## Import libraries
import cv2 # OpenCV library
import numpy as np # Numpy library for scientific computing
import matplotlib.pyplot as plt # Matplotlib library for plotting

## Change Colour space to HSV
img = cv2.imread('stop_shadow.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # OpenCV reads an image in the BGR order by default, this function can change the order to RGB
plt.figure(figsize = (9, 5))
plt.imshow(img_rgb)
plt.show()

# %%
px_rgb = img_rgb[100, 100] # pixel value at row = 100, column = 100
print(px_rgb)
px_rgb = img_rgb[400, 400] # pixel value at row = 400, column = 400
print(px_rgb)
# Out:
# [217  30  25]
# [150  21  16]

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # OpenCV reads an image in the BGR order by default, this function can change the order to RGB
px_hsv = img_hsv[100, 100] # pixel value at row = 100, column = 100
print(px_hsv)
px_hsv = img_hsv[400, 400] # pixel value at row = 400, column = 400
print(px_hsv)
# Out:
# [  1 226 217]
# [  1 228 150]

# %% [markdown]
# # Thresholding

# %% [markdown]
# ## Grayscale thresholding

# %%
# Import libraries
import cv2 
import numpy as np

def nothing(x): pass

# Load image
image = cv2.imread('opencv_logo.png')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL) 
cv2.resizeWindow('image', 900, 400)

# Create trackbars for thresholding
# Set thresh and maxval range from 0-255
cv2.createTrackbar('thresh', 'image', 0, 255, nothing) 
cv2.createTrackbar('maxval', 'image', 0, 255, nothing) 

# Set default value for thresh and maxval trackbars
cv2.setTrackbarPos('thresh', 'image', 0) 
cv2.setTrackbarPos('maxval', 'image', 255) 

# Initialize thresh and maxval values
thresh = maxval = 0 
pthresh = pmaxval = 0

while(1):

    # Get current positions of all trackbars
    thresh = cv2.getTrackbarPos('thresh', 'image')
    maxval = cv2.getTrackbarPos('maxval', 'image')

    # Convert to gray format and threshold
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, threshed = cv2.threshold(gray, thresh, maxval, cv2.THRESH_BINARY)
    
    # Convert grayscale image to color image for displaying simultaneous
    gray_3_channel = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)
    threshed_3_channel = cv2.cvtColor(threshed, cv2.COLOR_GRAY2BGR)
    
    # Stack images
    numpy_horizontal = np.hstack((image, gray_3_channel, threshed_3_channel))

    # Print if there is a change in threshold or maxval value
    if((pthresh != thresh) | (pmaxval != maxval)):
        print("(thresh = %d , maxval = %d)" % (thresh , maxval))
        pthresh = thresh
        pmaxval = maxval

    # Display stacked image, press q to quit
    cv2.imshow('image', numpy_horizontal)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (thresh = 0 , maxval = 255)
# (thresh = 1 , maxval = 255)
# (thresh = 2 , maxval = 255)
# (thresh = 4 , maxval = 255)
# (thresh = 5 , maxval = 255)
# (thresh = 8 , maxval = 255)
# (thresh = 9 , maxval = 255)
# (thresh = 10 , maxval = 255)
# (thresh = 12 , maxval = 255)
# (thresh = 14 , maxval = 255)
# (thresh = 15 , maxval = 255)
# (thresh = 17 , maxval = 255)
# (thresh = 18 , maxval = 255)
# (thresh = 19 , maxval = 255)
# (thresh = 21 , maxval = 255)
# (thresh = 23 , maxval = 255)
# (thresh = 24 , maxval = 255)
# (thresh = 25 , maxval = 255)
# (thresh = 26 , maxval = 255)
# (thresh = 28 , maxval = 255)
# (thresh = 30 , maxval = 255)
# (thresh = 31 , maxval = 255)
# (thresh = 32 , maxval = 255)
# (thresh = 33 , maxval = 255)
# (thresh = 34 , maxval = 255)
# (thresh = 35 , maxval = 255)
# (thresh = 36 , maxval = 255)
# (thresh = 37 , maxval = 255)
# (thresh = 38 , maxval = 255)
# (thresh = 42 , maxval = 255)
# (thresh = 43 , maxval = 255)
# (thresh = 44 , maxval = 255)
# (thresh = 45 , maxval = 255)
# (thresh = 46 , maxval = 255)
# (thresh = 47 , maxval = 255)
# (thresh = 48 , maxval = 255)
# (thresh = 50 , maxval = 255)
# (thresh = 52 , maxval = 255)
# (thresh = 53 , maxval = 255)
# (thresh = 54 , maxval = 255)
# (thresh = 55 , maxval = 255)
# (thresh = 57 , maxval = 255)
# (thresh = 59 , maxval = 255)
# (thresh = 64 , maxval = 255)
# (thresh = 66 , maxval = 255)
# (thresh = 67 , maxval = 255)
# (thresh = 68 , maxval = 255)
# (thresh = 69 , maxval = 255)
# (thresh = 70 , maxval = 255)
# (thresh = 71 , maxval = 255)
# (thresh = 73 , maxval = 255)
# (thresh = 76 , maxval = 255)
# (thresh = 80 , maxval = 255)
# (thresh = 81 , maxval = 255)
# (thresh = 82 , maxval = 255)
# (thresh = 84 , maxval = 255)
# (thresh = 85 , maxval = 255)
# (thresh = 86 , maxval = 255)
# (thresh = 87 , maxval = 255)
# (thresh = 88 , maxval = 255)
# (thresh = 89 , maxval = 255)
# (thresh = 91 , maxval = 255)
# (thresh = 92 , maxval = 255)
# (thresh = 94 , maxval = 255)
# (thresh = 95 , maxval = 255)
# (thresh = 96 , maxval = 255)
# (thresh = 98 , maxval = 255)
# (thresh = 99 , maxval = 255)
# (thresh = 101 , maxval = 255)
# (thresh = 105 , maxval = 255)
# (thresh = 107 , maxval = 255)
# (thresh = 108 , maxval = 255)
# (thresh = 109 , maxval = 255)
# (thresh = 110 , maxval = 255)
# (thresh = 111 , maxval = 255)
# (thresh = 112 , maxval = 255)
# (thresh = 113 , maxval = 255)
# (thresh = 114 , maxval = 255)
# (thresh = 115 , maxval = 255)
# (thresh = 117 , maxval = 255)
# (thresh = 118 , maxval = 255)
# (thresh = 119 , maxval = 255)
# (thresh = 121 , maxval = 255)
# (thresh = 123 , maxval = 255)
# (thresh = 124 , maxval = 255)
# (thresh = 126 , maxval = 255)
# (thresh = 127 , maxval = 255)
# (thresh = 128 , maxval = 255)
# (thresh = 129 , maxval = 255)
# (thresh = 132 , maxval = 255)
# (thresh = 134 , maxval = 255)
# (thresh = 136 , maxval = 255)
# (thresh = 137 , maxval = 255)
# (thresh = 138 , maxval = 255)
# (thresh = 140 , maxval = 255)
# (thresh = 141 , maxval = 255)
# (thresh = 142 , maxval = 255)
# (thresh = 143 , maxval = 255)
# (thresh = 145 , maxval = 255)
# (thresh = 146 , maxval = 255)
# (thresh = 149 , maxval = 255)
# (thresh = 150 , maxval = 255)
# (thresh = 152 , maxval = 255)
# (thresh = 153 , maxval = 255)
# (thresh = 154 , maxval = 255)
# (thresh = 156 , maxval = 255)
# (thresh = 157 , maxval = 255)
# (thresh = 158 , maxval = 255)
# (thresh = 159 , maxval = 255)
# (thresh = 160 , maxval = 255)
# (thresh = 161 , maxval = 255)
# (thresh = 162 , maxval = 255)
# (thresh = 164 , maxval = 255)
# (thresh = 169 , maxval = 255)
# (thresh = 170 , maxval = 255)
# (thresh = 171 , maxval = 255)
# (thresh = 172 , maxval = 255)
# (thresh = 173 , maxval = 255)
# (thresh = 174 , maxval = 255)
# (thresh = 175 , maxval = 255)
# (thresh = 176 , maxval = 255)
# (thresh = 177 , maxval = 255)
# (thresh = 179 , maxval = 255)
# (thresh = 180 , maxval = 255)
# (thresh = 181 , maxval = 255)
# (thresh = 183 , maxval = 255)
# (thresh = 184 , maxval = 255)
# (thresh = 186 , maxval = 255)
# (thresh = 188 , maxval = 255)
# (thresh = 189 , maxval = 255)
# (thresh = 192 , maxval = 255)
# (thresh = 193 , maxval = 255)
# (thresh = 195 , maxval = 255)
# (thresh = 196 , maxval = 255)
# (thresh = 197 , maxval = 255)
# (thresh = 198 , maxval = 255)
# (thresh = 200 , maxval = 255)
# (thresh = 202 , maxval = 255)
# (thresh = 203 , maxval = 255)
# (thresh = 206 , maxval = 255)
# (thresh = 207 , maxval = 255)
# (thresh = 208 , maxval = 255)
# (thresh = 212 , maxval = 255)
# (thresh = 214 , maxval = 255)
# (thresh = 216 , maxval = 255)
# (thresh = 217 , maxval = 255)
# (thresh = 219 , maxval = 255)
# (thresh = 222 , maxval = 255)
# (thresh = 223 , maxval = 255)
# (thresh = 224 , maxval = 255)
# (thresh = 225 , maxval = 255)
# (thresh = 226 , maxval = 255)
# (thresh = 227 , maxval = 255)
# (thresh = 228 , maxval = 255)
# (thresh = 229 , maxval = 255)
# (thresh = 230 , maxval = 255)
# (thresh = 231 , maxval = 255)
# (thresh = 232 , maxval = 255)
# (thresh = 234 , maxval = 255)
# (thresh = 235 , maxval = 255)
# (thresh = 236 , maxval = 255)
# (thresh = 239 , maxval = 255)
# (thresh = 240 , maxval = 255)
# (thresh = 241 , maxval = 255)
# (thresh = 242 , maxval = 255)
# (thresh = 244 , maxval = 255)
# (thresh = 236 , maxval = 255)
# (thresh = 206 , maxval = 255)
# (thresh = 180 , maxval = 255)
# (thresh = 152 , maxval = 255)
# (thresh = 146 , maxval = 255)
# (thresh = 144 , maxval = 255)
# (thresh = 135 , maxval = 255)
# (thresh = 132 , maxval = 255)
# (thresh = 131 , maxval = 255)
# (thresh = 127 , maxval = 255)
# (thresh = 125 , maxval = 255)
# (thresh = 120 , maxval = 255)
# (thresh = 118 , maxval = 255)
# (thresh = 104 , maxval = 255)
# (thresh = 100 , maxval = 255)
# (thresh = 94 , maxval = 255)
# (thresh = 90 , maxval = 255)
# (thresh = 87 , maxval = 255)
# (thresh = 81 , maxval = 255)
# (thresh = 78 , maxval = 255)
# (thresh = 77 , maxval = 255)
# (thresh = 73 , maxval = 255)
# (thresh = 70 , maxval = 255)
# (thresh = 69 , maxval = 255)
# (thresh = 65 , maxval = 255)
# (thresh = 63 , maxval = 255)
# (thresh = 62 , maxval = 255)
# (thresh = 60 , maxval = 255)
# (thresh = 58 , maxval = 255)
# (thresh = 56 , maxval = 255)
# (thresh = 53 , maxval = 255)
# (thresh = 51 , maxval = 255)
# (thresh = 47 , maxval = 255)
# (thresh = 44 , maxval = 255)
# (thresh = 41 , maxval = 255)
# (thresh = 39 , maxval = 255)
# (thresh = 36 , maxval = 255)
# (thresh = 33 , maxval = 255)
# (thresh = 29 , maxval = 255)
# (thresh = 23 , maxval = 255)
# (thresh = 21 , maxval = 255)
# (thresh = 19 , maxval = 255)
# (thresh = 16 , maxval = 255)
# (thresh = 15 , maxval = 255)
# (thresh = 14 , maxval = 255)
# (thresh = 12 , maxval = 255)
# (thresh = 10 , maxval = 255)
# (thresh = 8 , maxval = 255)
# (thresh = 7 , maxval = 255)
# (thresh = 5 , maxval = 255)
# (thresh = 3 , maxval = 255)
# (thresh = 2 , maxval = 255)
# (thresh = 0 , maxval = 255)
# (thresh = 0 , maxval = 254)
# (thresh = 0 , maxval = 251)
# (thresh = 0 , maxval = 248)
# (thresh = 0 , maxval = 247)
# (thresh = 0 , maxval = 245)
# (thresh = 0 , maxval = 244)
# (thresh = 0 , maxval = 242)
# (thresh = 0 , maxval = 241)
# (thresh = 0 , maxval = 237)
# (thresh = 0 , maxval = 236)
# (thresh = 0 , maxval = 232)
# (thresh = 0 , maxval = 231)
# (thresh = 0 , maxval = 230)
# (thresh = 0 , maxval = 228)
# (thresh = 0 , maxval = 227)
# (thresh = 0 , maxval = 226)
# (thresh = 0 , maxval = 224)
# (thresh = 0 , maxval = 223)
# (thresh = 0 , maxval = 222)
# (thresh = 0 , maxval = 220)
# (thresh = 0 , maxval = 218)
# (thresh = 0 , maxval = 217)
# (thresh = 0 , maxval = 216)
# (thresh = 0 , maxval = 215)
# (thresh = 0 , maxval = 213)
# (thresh = 0 , maxval = 212)
# (thresh = 0 , maxval = 211)
# (thresh = 0 , maxval = 208)
# (thresh = 0 , maxval = 207)
# (thresh = 0 , maxval = 205)
# (thresh = 0 , maxval = 203)
# (thresh = 0 , maxval = 200)
# (thresh = 0 , maxval = 198)
# (thresh = 0 , maxval = 195)
# (thresh = 0 , maxval = 192)
# (thresh = 0 , maxval = 190)
# (thresh = 0 , maxval = 184)
# (thresh = 0 , maxval = 180)
# (thresh = 0 , maxval = 178)
# (thresh = 0 , maxval = 176)
# (thresh = 0 , maxval = 173)
# (thresh = 0 , maxval = 172)
# (thresh = 0 , maxval = 171)
# (thresh = 0 , maxval = 170)
# (thresh = 0 , maxval = 168)
# (thresh = 0 , maxval = 167)
# (thresh = 0 , maxval = 166)
# (thresh = 0 , maxval = 165)
# (thresh = 0 , maxval = 164)
# (thresh = 0 , maxval = 162)
# (thresh = 0 , maxval = 161)
# (thresh = 0 , maxval = 159)
# (thresh = 0 , maxval = 158)
# (thresh = 0 , maxval = 157)
# (thresh = 0 , maxval = 156)
# (thresh = 0 , maxval = 153)
# (thresh = 0 , maxval = 151)
# (thresh = 0 , maxval = 149)
# (thresh = 0 , maxval = 148)
# (thresh = 0 , maxval = 146)
# (thresh = 0 , maxval = 142)
# (thresh = 0 , maxval = 138)
# (thresh = 0 , maxval = 137)
# (thresh = 0 , maxval = 136)
# (thresh = 0 , maxval = 134)
# (thresh = 0 , maxval = 130)
# (thresh = 0 , maxval = 129)
# (thresh = 0 , maxval = 126)
# (thresh = 0 , maxval = 124)
# (thresh = 0 , maxval = 122)
# (thresh = 0 , maxval = 120)
# (thresh = 0 , maxval = 117)
# (thresh = 0 , maxval = 116)
# (thresh = 0 , maxval = 115)
# (thresh = 0 , maxval = 113)
# (thresh = 0 , maxval = 112)
# (thresh = 0 , maxval = 111)
# (thresh = 0 , maxval = 110)
# (thresh = 0 , maxval = 108)
# (thresh = 0 , maxval = 107)
# (thresh = 0 , maxval = 106)
# (thresh = 0 , maxval = 100)
# (thresh = 0 , maxval = 99)
# (thresh = 0 , maxval = 98)
# (thresh = 0 , maxval = 96)
# (thresh = 0 , maxval = 95)
# (thresh = 0 , maxval = 93)
# (thresh = 0 , maxval = 92)
# (thresh = 0 , maxval = 90)
# (thresh = 0 , maxval = 89)
# (thresh = 0 , maxval = 88)
# (thresh = 0 , maxval = 87)
# (thresh = 0 , maxval = 82)
# (thresh = 0 , maxval = 81)
# (thresh = 0 , maxval = 80)
# (thresh = 0 , maxval = 79)
# (thresh = 0 , maxval = 78)
# (thresh = 0 , maxval = 77)
# (thresh = 0 , maxval = 76)
# (thresh = 0 , maxval = 75)
# (thresh = 0 , maxval = 74)
# (thresh = 0 , maxval = 73)
# (thresh = 0 , maxval = 72)
# (thresh = 0 , maxval = 71)
# (thresh = 0 , maxval = 70)
# (thresh = 0 , maxval = 69)
# (thresh = 0 , maxval = 68)
# (thresh = 0 , maxval = 67)
# (thresh = 0 , maxval = 66)
# (thresh = 0 , maxval = 65)
# (thresh = 0 , maxval = 64)
# (thresh = 0 , maxval = 63)
# (thresh = 0 , maxval = 62)
# (thresh = 0 , maxval = 59)
# (thresh = 0 , maxval = 57)
# (thresh = 0 , maxval = 54)
# (thresh = 0 , maxval = 53)
# (thresh = 0 , maxval = 52)
# (thresh = 0 , maxval = 51)
# (thresh = 0 , maxval = 50)
# (thresh = 0 , maxval = 49)
# (thresh = 0 , maxval = 48)
# (thresh = 0 , maxval = 47)
# (thresh = 0 , maxval = 46)
# (thresh = 0 , maxval = 45)
# (thresh = 0 , maxval = 44)
# (thresh = 0 , maxval = 43)
# (thresh = 0 , maxval = 42)
# (thresh = 0 , maxval = 41)
# (thresh = 0 , maxval = 40)
# (thresh = 0 , maxval = 39)
# (thresh = 0 , maxval = 38)
# (thresh = 0 , maxval = 37)
# (thresh = 0 , maxval = 36)
# (thresh = 0 , maxval = 38)
# (thresh = 0 , maxval = 40)
# (thresh = 0 , maxval = 42)
# (thresh = 0 , maxval = 45)
# (thresh = 0 , maxval = 48)
# (thresh = 0 , maxval = 53)
# (thresh = 0 , maxval = 55)
# (thresh = 0 , maxval = 77)
# (thresh = 0 , maxval = 85)
# (thresh = 0 , maxval = 93)
# (thresh = 0 , maxval = 97)
# (thresh = 0 , maxval = 102)
# (thresh = 0 , maxval = 113)
# (thresh = 0 , maxval = 119)
# (thresh = 0 , maxval = 124)
# (thresh = 0 , maxval = 127)
# (thresh = 0 , maxval = 131)
# (thresh = 0 , maxval = 135)
# (thresh = 0 , maxval = 150)
# (thresh = 0 , maxval = 174)
# (thresh = 0 , maxval = 182)
# (thresh = 0 , maxval = 192)
# (thresh = 0 , maxval = 197)
# (thresh = 0 , maxval = 199)
# (thresh = 0 , maxval = 201)
# (thresh = 0 , maxval = 205)
# (thresh = 0 , maxval = 208)
# (thresh = 0 , maxval = 213)
# (thresh = 0 , maxval = 216)
# (thresh = 0 , maxval = 220)
# (thresh = 0 , maxval = 222)
# (thresh = 0 , maxval = 226)
# (thresh = 0 , maxval = 232)
# (thresh = 0 , maxval = 233)
# (thresh = 0 , maxval = 234)
# (thresh = 0 , maxval = 236)
# (thresh = 0 , maxval = 237)
# (thresh = 0 , maxval = 240)
# (thresh = 0 , maxval = 246)
# (thresh = 0 , maxval = 252)
# (thresh = 0 , maxval = 255)

# %% [markdown]
# ## Colour-based thresholding

# %%
# Import libraries
import cv2 
import numpy as np

def nothing(x): pass

# Load image
image = cv2.imread('opencv_logo.png')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL) 
cv2.resizeWindow('image', 900, 700)

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMin', 'image', 0, 255, nothing) 
cv2.createTrackbar('HMax', 'image', 0, 179, nothing) 
cv2.createTrackbar('SMax', 'image', 0, 255, nothing) 
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179) 
cv2.setTrackbarPos('SMax', 'image', 255) 
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0 
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):

    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)
    
    # Convert grayscale image to color image for displaying simultaneous
    mask_3_channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
    
    # Stack images
    numpy_horizontal = np.hstack((image, result, mask_3_channel))
    
    # Display HSV values of some colours
    cv2.putText(numpy_horizontal, 'Black: (0, 0, 0)', (130, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'White: (0, 0, 255)', (130, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Red: (0, 255, 255)', (130, 45), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Green: (60, 255, 255)', (130, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)
    cv2.putText(numpy_horizontal, 'Blue: (120, 255, 255)', (130, 75), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,255), 1, cv2.LINE_AA)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display stacked image, press q to quit
    cv2.imshow('image', numpy_horizontal)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 40 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 41 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 44 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 45 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 57 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 60 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 67 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 59 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 43 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 156 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 126 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 122 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 104 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 98 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 96 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 94 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 92 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 89 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 87 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 80 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 78 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 77 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 76 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 75 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 72 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 71 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 69 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 68 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 67 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 66 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 65 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 64 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 63 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 62 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 61 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 60 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 63 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 66 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 96 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 119 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)

# %% [markdown]
# # Morphological transformations

# %% [markdown]
# ## Import libraries

# %%
import cv2 # OpenCV library
import numpy as np # Numpy library for scientific computing
import matplotlib.pyplot as plt # Matplotlib library for plotting

# %% [markdown]
# ## Prepare image and kernel

# %%
img = cv2.imread('fingerprint.png',cv2.IMREAD_GRAYSCALE)
kernel = np.ones((3,3), np.uint8)

# %% [markdown]
# ## Erosion

# %%
erosion = cv2.erode(img, kernel, iterations = 1)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(erosion, cmap='gray'), ax2.set_title("Erosion")
plt.show()

# %% [markdown]
# ## Dilation

# %%
dilation = cv2.dilate(img, kernel, iterations = 1)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(dilation, cmap='gray'), ax2.set_title("Dilation")
plt.show()

# %% [markdown]
# ## Opening

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(opening, cmap='gray'), ax2.set_title("Opening")
plt.show()

# %% [markdown]
# ## Closing

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(closing, cmap='gray'), ax2.set_title("Closing")
plt.show()

# %% [markdown]
# ## Opening after Closing

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
opening = cv2.morphologyEx(closing, cv2.MORPH_OPEN, kernel)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(opening, cmap='gray'), ax2.set_title("Opening after Closing")
plt.show()

# %% [markdown]
# ## Closing after Opening

# %%
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
fig, (ax1, ax2) = plt.subplots(figsize = (9, 5), ncols = 2)
ax1.imshow(img, cmap='gray'), ax1.set_title("Original")
ax2.imshow(closing, cmap='gray'), ax2.set_title("Closing after Opening")
plt.show()
